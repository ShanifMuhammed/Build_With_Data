# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s5e7/sample_submission.csv
# /kaggle/input/playground-series-s5e7/train.csv
# /kaggle/input/playground-series-s5e7/test.csv

# %%
df=pd.read_csv('/kaggle/input/playground-series-s5e7/train.csv')
df_test=pd.read_csv('/kaggle/input/playground-series-s5e7/test.csv')
df_sample_submission=pd.read_csv('/kaggle/input/playground-series-s5e7/sample_submission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (18524, 9)

# %%
df['Personality'].value_counts()
# Out:
# Personality
# Extrovert    13699
# Introvert     4825
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
print(df['Stage_fear'].unique())
print(df['Drained_after_socializing'].unique())
# Out:
# ['No' 'Yes' nan]
# ['No' nan 'Yes']

# %%
mapping = {'Yes': 1, 'No': 0}
df['Stage_fear'] = df['Stage_fear'].map(mapping)

mapping1 = {'Yes': 1, 'No': 0}
df['Drained_after_socializing'] = df['Drained_after_socializing'].map(mapping1)

mapping2 = {'Extrovert': 1, 'Introvert': 0}
df['Personality'] = df['Personality'].map(mapping2)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         0.0                      6.0            4.0
# 1   1               1.0         0.0                      7.0            3.0
# 2   2               6.0         1.0                      1.0            0.0
# 3   3               3.0         0.0                      7.0            3.0
# 4   4               1.0         0.0                      4.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        0.0                 15.0             5.0            1
# 1                        0.0                 10.0             8.0            1
# 2                        NaN                  3.0             0.0            0
# 3                        0.0                 11.0             5.0            1
# 4                        0.0                 13.0             NaN            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  float64
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  float64
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

num_cols = ['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
            'Going_outside', 'Drained_after_socializing',
            'Friends_circle_size', 'Post_frequency']

imputer = KNNImputer(n_neighbors=5)
df[num_cols] = imputer.fit_transform(df[num_cols])

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
import optuna
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import numpy as np

num_cols = [
    'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
    'Going_outside', 'Drained_after_socializing',
    'Friends_circle_size', 'Post_frequency'
]

X = df[num_cols]
y = df['Personality']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

def objective(trial):
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
    splitter = trial.suggest_categorical('splitter', ['best', 'random'])
    max_depth = trial.suggest_int('max_depth', 3, 150)  # increased range
    min_samples_split = trial.suggest_int('min_samples_split', 2, 50)  # more flexibility
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 25)
    max_features = trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])
    ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.03, step=0.002)  # pruning strength

    model = DecisionTreeClassifier(
        criterion=criterion,
        splitter=splitter,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        class_weight=class_weight,
        ccp_alpha=ccp_alpha,
        random_state=42
    )

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1_macro')
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)  # increased to 100 trials

print("\n🎯 Best Hyperparameters Found:")
print(study.best_params)

best_params = study.best_params
best_model = DecisionTreeClassifier(
    **best_params,
    random_state=42
)
best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

print("\n✅ Model Performance on Test Set:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred, average='macro'))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# [I 2025-10-16 15:34:29,841] A new study created in memory with name: no-name-98857590-2cf6-431f-b1f0-14301a6c3cb2
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-16 15:34:29,957] Trial 0 finished with value: 0.9544240886407458 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced', 'ccp_alpha': 0.008}. Best is trial 0 with value: 0.9544240886407458.
# [I 2025-10-16 15:34:30,044] Trial 1 finished with value: 0.9593183041463025 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 92, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.006}. Best is trial 1 with value: 0.9593183041463025.
# [I 2025-10-16 15:34:30,118] Trial 2 finished with value: 0.9593489094065072 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 118, 'min_samples_split': 25, 'min_samples_leaf': 2, 'max_features': 'log2', 'class_weight': 'balanced', 'ccp_alpha': 0.012}. Best is trial 2 with value: 0.9593489094065072.
# [I 2025-10-16 15:34:30,203] Trial 3 finished with value: 0.9601157534245756 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 119, 'min_samples_split': 43, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.002}. Best is trial 3 with value: 0.9601157534245756.
# [I 2025-10-16 15:34:30,295] Trial 4 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 49, 'min_samples_split': 6, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,383] Trial 5 finished with value: 0.9573167986773379 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 105, 'min_samples_split': 45, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,461] Trial 6 finished with value: 0.9528656250146674 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 99, 'min_samples_split': 33, 'min_samples_leaf': 20, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.03}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,547] Trial 7 finished with value: 0.9540881874222886 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 134, 'min_samples_split': 48, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.03}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,616] Trial 8 finished with value: 0.9579763123459056 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 56, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': 'log2', 'class_weight': 'balanced', 'ccp_alpha': 0.01}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,774] Trial 9 finished with value: 0.9605459219153468 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 133, 'min_samples_split': 28, 'min_samples_leaf': 11, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,872] Trial 10 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 53, 'min_samples_split': 15, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:30,965] Trial 11 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 47, 'min_samples_split': 16, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,066] Trial 12 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 58, 'min_samples_split': 15, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,162] Trial 13 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 19, 'min_samples_split': 14, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,263] Trial 14 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 37, 'min_samples_split': 21, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,361] Trial 15 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 77, 'min_samples_split': 10, 'min_samples_leaf': 21, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,425] Trial 16 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,530] Trial 17 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 75, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,641] Trial 18 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 17, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,739] Trial 19 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 66, 'min_samples_split': 36, 'min_samples_leaf': 22, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,843] Trial 20 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 150, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:31,937] Trial 21 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 47, 'min_samples_split': 16, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,032] Trial 22 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 39, 'min_samples_split': 22, 'min_samples_leaf': 23, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,129] Trial 23 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 78, 'min_samples_split': 13, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,227] Trial 24 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 48, 'min_samples_split': 19, 'min_samples_leaf': 18, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,323] Trial 25 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 22, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,434] Trial 26 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 69, 'min_samples_split': 26, 'min_samples_leaf': 16, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,535] Trial 27 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 53, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,602] Trial 28 finished with value: 0.9595570341300915 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 20, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,677] Trial 29 finished with value: 0.9399562665873582 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,743] Trial 30 finished with value: 0.9580395826682327 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 83, 'min_samples_split': 6, 'min_samples_leaf': 23, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,845] Trial 31 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 61, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:32,954] Trial 32 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 46, 'min_samples_split': 22, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.008}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,061] Trial 33 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 60, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,221] Trial 34 finished with value: 0.9605459219153468 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 89, 'min_samples_split': 30, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,288] Trial 35 finished with value: 0.959472554545217 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 41, 'min_samples_split': 8, 'min_samples_leaf': 19, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,378] Trial 36 finished with value: 0.9550571278905926 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 27, 'min_samples_split': 23, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,483] Trial 37 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 66, 'min_samples_split': 4, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.012}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,580] Trial 38 finished with value: 0.9576599180605117 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 53, 'min_samples_split': 38, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,650] Trial 39 finished with value: 0.9592337527553318 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 98, 'min_samples_split': 25, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,758] Trial 40 finished with value: 0.9606308442756193 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 70, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,854] Trial 41 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:33,947] Trial 42 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 15, 'min_samples_split': 18, 'min_samples_leaf': 23, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,050] Trial 43 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 21, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.03}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,144] Trial 44 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 59, 'min_samples_split': 20, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,296] Trial 45 finished with value: 0.9605459219153468 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 44, 'min_samples_split': 11, 'min_samples_leaf': 21, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,389] Trial 46 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 34, 'min_samples_split': 14, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,457] Trial 47 finished with value: 0.9587651866197469 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 111, 'min_samples_split': 29, 'min_samples_leaf': 17, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,544] Trial 48 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 22, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,717] Trial 49 finished with value: 0.9605459219153468 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 53, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,840] Trial 50 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 86, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:34,944] Trial 51 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 39, 'min_samples_split': 21, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,047] Trial 52 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 29, 'min_samples_split': 19, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,154] Trial 53 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 21, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,261] Trial 54 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 37, 'min_samples_split': 24, 'min_samples_leaf': 12, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,360] Trial 55 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 49, 'min_samples_split': 50, 'min_samples_leaf': 16, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,451] Trial 56 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 63, 'min_samples_split': 12, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,528] Trial 57 finished with value: 0.958759253028799 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 72, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.01}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,648] Trial 58 finished with value: 0.9606308442756193 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 43, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,764] Trial 59 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 56, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,844] Trial 60 finished with value: 0.9595570341300915 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 34, 'min_samples_split': 27, 'min_samples_leaf': 20, 'max_features': 'log2', 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:35,937] Trial 61 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 50, 'min_samples_split': 11, 'min_samples_leaf': 23, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,033] Trial 62 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 82, 'min_samples_split': 4, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.004}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,131] Trial 63 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 73, 'min_samples_split': 9, 'min_samples_leaf': 21, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,231] Trial 64 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 77, 'min_samples_split': 13, 'min_samples_leaf': 18, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,332] Trial 65 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 56, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,429] Trial 66 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 65, 'min_samples_split': 7, 'min_samples_leaf': 22, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,577] Trial 67 finished with value: 0.9605459219153468 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,646] Trial 68 finished with value: 0.9580005106784129 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 94, 'min_samples_split': 17, 'min_samples_leaf': 25, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,735] Trial 69 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 11, 'min_samples_split': 22, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,849] Trial 70 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,921] Trial 71 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:36,999] Trial 72 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 16, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,104] Trial 73 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.028}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,211] Trial 74 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 47, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,278] Trial 75 finished with value: 0.9508730051263143 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 24, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,383] Trial 76 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 38, 'min_samples_split': 21, 'min_samples_leaf': 12, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,506] Trial 77 finished with value: 0.9605459219153468 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 8, 'min_samples_split': 44, 'min_samples_leaf': 24, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.03}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,608] Trial 78 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 69, 'min_samples_split': 2, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,675] Trial 79 finished with value: 0.9587651866197469 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 58, 'min_samples_split': 24, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,790] Trial 80 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 52, 'min_samples_split': 16, 'min_samples_leaf': 21, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:37,909] Trial 81 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 81, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,019] Trial 82 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 62, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,128] Trial 83 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 131, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,223] Trial 84 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 42, 'min_samples_split': 9, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.01}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,318] Trial 85 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 76, 'min_samples_split': 14, 'min_samples_leaf': 22, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,429] Trial 86 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 67, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,499] Trial 87 finished with value: 0.9593247805937566 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 24, 'max_features': 'log2', 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,661] Trial 88 finished with value: 0.9605459219153468 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 88, 'min_samples_split': 20, 'min_samples_leaf': 11, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,758] Trial 89 finished with value: 0.9606308442756193 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 102, 'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.0}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,865] Trial 90 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 44, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:38,980] Trial 91 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 37, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,095] Trial 92 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 16, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,209] Trial 93 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 14, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,320] Trial 94 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 23, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,437] Trial 95 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 49, 'min_samples_split': 5, 'min_samples_leaf': 15, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,542] Trial 96 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 41, 'min_samples_split': 33, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,616] Trial 97 finished with value: 0.9560765975122486 and parameters: {'criterion': 'log_loss', 'splitter': 'random', 'max_depth': 54, 'min_samples_split': 11, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'class_weight': None, 'ccp_alpha': 0.024}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,715] Trial 98 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 59, 'min_samples_split': 18, 'min_samples_leaf': 19, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 4 with value: 0.9606308442756193.
# [I 2025-10-16 15:34:39,825] Trial 99 finished with value: 0.9606308442756193 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 25, 'max_features': None, 'class_weight': 'balanced', 'ccp_alpha': 0.022}. Best is trial 4 with value: 0.9606308442756193.
#
# 🎯 Best Hyperparameters Found:
# {'criterion': 'gini', 'splitter': 'random', 'max_depth': 49, 'min_samples_split': 6, 'min_samples_leaf': 13, 'max_features': None, 'class_weight': None, 'ccp_alpha': 0.026000000000000002}
#
# ✅ Model Performance on Test Set:
# Accuracy: 0.9651821862348178
# F1 Score: 0.9544875359106573
# Confusion Matrix:
#  [[ 890   75]
#  [  54 2686]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.95      0.95      3705
# weighted avg       0.97      0.97      0.97      3705

# %%
from sklearn.metrics import roc_auc_score
print("ROC-AUC:", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))
# Out:
# ROC-AUC: 0.9512858817745168
