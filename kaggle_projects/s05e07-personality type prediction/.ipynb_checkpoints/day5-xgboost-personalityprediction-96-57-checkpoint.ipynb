# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s5e7/sample_submission.csv
# /kaggle/input/playground-series-s5e7/train.csv
# /kaggle/input/playground-series-s5e7/test.csv

# %%
df=pd.read_csv('/kaggle/input/playground-series-s5e7/train.csv')
df_test=pd.read_csv('/kaggle/input/playground-series-s5e7/test.csv')
df_sample_submission=pd.read_csv('/kaggle/input/playground-series-s5e7/sample_submission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (18524, 9)

# %%
df['Personality'].value_counts()
# Out:
# Personality
# Extrovert    13699
# Introvert     4825
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
print(df['Stage_fear'].unique())
print(df['Drained_after_socializing'].unique())
# Out:
# ['No' 'Yes' nan]
# ['No' nan 'Yes']

# %%
mapping = {'Yes': 1, 'No': 0}
df['Stage_fear'] = df['Stage_fear'].map(mapping)

mapping1 = {'Yes': 1, 'No': 0}
df['Drained_after_socializing'] = df['Drained_after_socializing'].map(mapping1)

mapping2 = {'Extrovert': 1, 'Introvert': 0}
df['Personality'] = df['Personality'].map(mapping2)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         0.0                      6.0            4.0
# 1   1               1.0         0.0                      7.0            3.0
# 2   2               6.0         1.0                      1.0            0.0
# 3   3               3.0         0.0                      7.0            3.0
# 4   4               1.0         0.0                      4.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        0.0                 15.0             5.0            1
# 1                        0.0                 10.0             8.0            1
# 2                        NaN                  3.0             0.0            0
# 3                        0.0                 11.0             5.0            1
# 4                        0.0                 13.0             NaN            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  float64
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  float64
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

num_cols = ['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
            'Going_outside', 'Drained_after_socializing',
            'Friends_circle_size', 'Post_frequency']

imputer = KNNImputer(n_neighbors=5)
df[num_cols] = imputer.fit_transform(df[num_cols])

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py:499: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(distances, out=distances)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py:499: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(distances, out=distances)

# %%
df.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
import numpy as np

num_cols = [
    'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
    'Going_outside', 'Drained_after_socializing',
    'Friends_circle_size', 'Post_frequency'
]

X = df[num_cols]
y = df['Personality']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1.0, 5.0),  # for imbalance
        'use_label_encoder': False,
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'random_state': 42
    }

    model = XGBClassifier(**params)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1_macro')
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, show_progress_bar=True)

print("\n🎯 Best Hyperparameters Found:")
print(study.best_params)

best_params = study.best_params
best_model = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=42)
best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

print("\n✅ Model Performance on Test Set:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred, average='macro'))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# [I 2025-10-19 16:42:38,870] A new study created in memory with name: no-name-f3bedc56-1c8c-46d5-a100-056c3d2bcd0e
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-10-19 16:42:40,166] Trial 0 finished with value: 0.9602573245887533 and parameters: {'n_estimators': 807, 'max_depth': 15, 'learning_rate': 0.22744990003982307, 'subsample': 0.6270844316126998, 'colsample_bytree': 0.5718068037138639, 'gamma': 6.565448777679498, 'reg_alpha': 7.9728775278621775, 'reg_lambda': 7.905458944967091, 'min_child_weight': 9, 'scale_pos_weight': 1.684431677581209}. Best is trial 0 with value: 0.9602573245887533.
# [I 2025-10-19 16:42:40,859] Trial 1 finished with value: 0.9609043670201183 and parameters: {'n_estimators': 359, 'max_depth': 12, 'learning_rate': 0.025439207403655066, 'subsample': 0.8270103681648009, 'colsample_bytree': 0.5771991968642618, 'gamma': 6.559920751141909, 'reg_alpha': 6.4620229650535155, 'reg_lambda': 5.7823489688205685, 'min_child_weight': 4, 'scale_pos_weight': 1.7311723633944207}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:42,438] Trial 2 finished with value: 0.9582301454941422 and parameters: {'n_estimators': 563, 'max_depth': 7, 'learning_rate': 0.010161991025275235, 'subsample': 0.8811601924071714, 'colsample_bytree': 0.9425231252194631, 'gamma': 3.250567145014036, 'reg_alpha': 3.1863614629184314, 'reg_lambda': 2.1808919000312676, 'min_child_weight': 6, 'scale_pos_weight': 4.223527450607273}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:43,546] Trial 3 finished with value: 0.958149662260093 and parameters: {'n_estimators': 791, 'max_depth': 14, 'learning_rate': 0.2677311356454447, 'subsample': 0.8753356262927289, 'colsample_bytree': 0.8255156305751841, 'gamma': 6.1179500168936745, 'reg_alpha': 7.832233953153857, 'reg_lambda': 1.9015394619540127, 'min_child_weight': 3, 'scale_pos_weight': 4.173208646319479}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:45,575] Trial 4 finished with value: 0.9563497940983071 and parameters: {'n_estimators': 470, 'max_depth': 10, 'learning_rate': 0.02303732143530928, 'subsample': 0.5270751621724575, 'colsample_bytree': 0.8089725983456175, 'gamma': 0.8892620269248408, 'reg_alpha': 1.5055614628647362, 'reg_lambda': 8.434892712966978, 'min_child_weight': 1, 'scale_pos_weight': 4.628973081578138}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:46,084] Trial 5 finished with value: 0.9588758322957212 and parameters: {'n_estimators': 276, 'max_depth': 13, 'learning_rate': 0.10541278151837773, 'subsample': 0.5757591485386726, 'colsample_bytree': 0.5710909864128338, 'gamma': 7.0433946012188215, 'reg_alpha': 7.525277751592348, 'reg_lambda': 0.7289250997141294, 'min_child_weight': 5, 'scale_pos_weight': 4.216961025538934}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:46,437] Trial 6 finished with value: 0.9605976300288503 and parameters: {'n_estimators': 161, 'max_depth': 9, 'learning_rate': 0.10796900849074943, 'subsample': 0.5327939499536677, 'colsample_bytree': 0.8026036306809348, 'gamma': 3.895659362075677, 'reg_alpha': 8.221846311590479, 'reg_lambda': 0.06953842533954924, 'min_child_weight': 1, 'scale_pos_weight': 2.2492088425184686}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:47,173] Trial 7 finished with value: 0.954867306120408 and parameters: {'n_estimators': 217, 'max_depth': 15, 'learning_rate': 0.09822981673569596, 'subsample': 0.9790588997807732, 'colsample_bytree': 0.7465711588217904, 'gamma': 0.1220387662664868, 'reg_alpha': 5.574097564392196, 'reg_lambda': 2.9319968042308773, 'min_child_weight': 4, 'scale_pos_weight': 4.698954527813614}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:47,704] Trial 8 finished with value: 0.9586426857496001 and parameters: {'n_estimators': 303, 'max_depth': 5, 'learning_rate': 0.09790733771294038, 'subsample': 0.9450430142295594, 'colsample_bytree': 0.7884468750468002, 'gamma': 7.100639524712723, 'reg_alpha': 1.1614897892290887, 'reg_lambda': 2.373068024722662, 'min_child_weight': 1, 'scale_pos_weight': 4.843862779008681}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:48,098] Trial 9 finished with value: 0.9608197592527776 and parameters: {'n_estimators': 235, 'max_depth': 12, 'learning_rate': 0.21475860852968454, 'subsample': 0.9449822765984859, 'colsample_bytree': 0.8336708301162108, 'gamma': 9.152487101132817, 'reg_alpha': 6.455780248811495, 'reg_lambda': 5.169902083781279, 'min_child_weight': 7, 'scale_pos_weight': 1.5337073657695837}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:49,707] Trial 10 finished with value: 0.9603292474349112 and parameters: {'n_estimators': 999, 'max_depth': 3, 'learning_rate': 0.03079293212002538, 'subsample': 0.7330529976814396, 'colsample_bytree': 0.513152584084786, 'gamma': 9.975321538216928, 'reg_alpha': 9.866782934098893, 'reg_lambda': 5.9532924452228615, 'min_child_weight': 10, 'scale_pos_weight': 2.9293650992392104}. Best is trial 1 with value: 0.9609043670201183.
# [I 2025-10-19 16:42:50,462] Trial 11 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 445, 'max_depth': 11, 'learning_rate': 0.03636099981392912, 'subsample': 0.7903705928435776, 'colsample_bytree': 0.6715685209202545, 'gamma': 9.640929916815468, 'reg_alpha': 5.108652304372666, 'reg_lambda': 5.1492590305143615, 'min_child_weight': 7, 'scale_pos_weight': 1.1011258579682486}. Best is trial 11 with value: 0.9609167020916234.
# [I 2025-10-19 16:42:51,267] Trial 12 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 456, 'max_depth': 11, 'learning_rate': 0.029468544987753448, 'subsample': 0.7557394828560364, 'colsample_bytree': 0.6754429275710032, 'gamma': 8.69355495976898, 'reg_alpha': 4.102536096987766, 'reg_lambda': 6.682841090212673, 'min_child_weight': 8, 'scale_pos_weight': 1.0681721568776807}. Best is trial 11 with value: 0.9609167020916234.
# [I 2025-10-19 16:42:52,150] Trial 13 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 540, 'max_depth': 10, 'learning_rate': 0.04164948028731936, 'subsample': 0.7198042075436818, 'colsample_bytree': 0.6777929538870837, 'gamma': 8.646373365932366, 'reg_alpha': 3.6610487541196988, 'reg_lambda': 6.9202091521329585, 'min_child_weight': 8, 'scale_pos_weight': 1.0367186208831671}. Best is trial 11 with value: 0.9609167020916234.
# [I 2025-10-19 16:42:53,320] Trial 14 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 676, 'max_depth': 8, 'learning_rate': 0.014848576838830833, 'subsample': 0.790492234569374, 'colsample_bytree': 0.685078778859277, 'gamma': 8.228185984058475, 'reg_alpha': 4.252941446467011, 'reg_lambda': 9.56666355635566, 'min_child_weight': 7, 'scale_pos_weight': 1.0656692978642335}. Best is trial 11 with value: 0.9609167020916234.
# [I 2025-10-19 16:42:54,087] Trial 15 finished with value: 0.960238020575974 and parameters: {'n_estimators': 450, 'max_depth': 11, 'learning_rate': 0.05684678534082347, 'subsample': 0.6726717081976803, 'colsample_bytree': 0.6695701688646933, 'gamma': 9.736885336503033, 'reg_alpha': 2.640729479272828, 'reg_lambda': 4.2517744947218254, 'min_child_weight': 9, 'scale_pos_weight': 2.838245133544601}. Best is trial 11 with value: 0.9609167020916234.
# [I 2025-10-19 16:42:54,786] Trial 16 finished with value: 0.9609551732670024 and parameters: {'n_estimators': 385, 'max_depth': 6, 'learning_rate': 0.061215331052401074, 'subsample': 0.7746865028241396, 'colsample_bytree': 0.9035869528113998, 'gamma': 4.953629107849664, 'reg_alpha': 4.692219679731343, 'reg_lambda': 3.85056643205355, 'min_child_weight': 7, 'scale_pos_weight': 2.3160400925498426}. Best is trial 16 with value: 0.9609551732670024.
# [I 2025-10-19 16:42:55,127] Trial 17 finished with value: 0.9606892730749973 and parameters: {'n_estimators': 119, 'max_depth': 6, 'learning_rate': 0.05699418429983016, 'subsample': 0.8304910275599375, 'colsample_bytree': 0.9526582005344124, 'gamma': 4.568211040693167, 'reg_alpha': 5.256941150698747, 'reg_lambda': 4.058277713563505, 'min_child_weight': 6, 'scale_pos_weight': 2.2625186802060595}. Best is trial 16 with value: 0.9609551732670024.
# [I 2025-10-19 16:42:56,093] Trial 18 finished with value: 0.9587880580694478 and parameters: {'n_estimators': 372, 'max_depth': 4, 'learning_rate': 0.0699543020388616, 'subsample': 0.6734668045802228, 'colsample_bytree': 0.896136522537478, 'gamma': 2.7548451654498094, 'reg_alpha': 0.14298847100327983, 'reg_lambda': 3.8665255320753196, 'min_child_weight': 7, 'scale_pos_weight': 3.5949150321319925}. Best is trial 16 with value: 0.9609551732670024.
# [I 2025-10-19 16:42:57,164] Trial 19 finished with value: 0.9603225297921985 and parameters: {'n_estimators': 628, 'max_depth': 7, 'learning_rate': 0.04057403419758393, 'subsample': 0.7866764306675257, 'colsample_bytree': 0.993528342089936, 'gamma': 5.560216329790417, 'reg_alpha': 2.3588222489340955, 'reg_lambda': 3.213384903855367, 'min_child_weight': 5, 'scale_pos_weight': 2.4377523319333907}. Best is trial 16 with value: 0.9609551732670024.
# [I 2025-10-19 16:42:57,872] Trial 20 finished with value: 0.9599030737149248 and parameters: {'n_estimators': 373, 'max_depth': 8, 'learning_rate': 0.14618842228180512, 'subsample': 0.8786763171935685, 'colsample_bytree': 0.8883381158871415, 'gamma': 1.4325952355980678, 'reg_alpha': 5.987632771162133, 'reg_lambda': 4.827400907128313, 'min_child_weight': 10, 'scale_pos_weight': 3.3975059288938194}. Best is trial 16 with value: 0.9609551732670024.
# [I 2025-10-19 16:42:58,860] Trial 21 finished with value: 0.9610861087155851 and parameters: {'n_estimators': 471, 'max_depth': 11, 'learning_rate': 0.018762076736582034, 'subsample': 0.7662591134439221, 'colsample_bytree': 0.7255777700507887, 'gamma': 7.949996256795501, 'reg_alpha': 4.342711681883762, 'reg_lambda': 6.657600277501226, 'min_child_weight': 8, 'scale_pos_weight': 1.3806493433723197}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:42:59,860] Trial 22 finished with value: 0.9609954837679199 and parameters: {'n_estimators': 516, 'max_depth': 9, 'learning_rate': 0.017209112132041994, 'subsample': 0.6979010895128702, 'colsample_bytree': 0.7415835588119639, 'gamma': 7.801521863616067, 'reg_alpha': 4.605699265871426, 'reg_lambda': 7.113738799708365, 'min_child_weight': 8, 'scale_pos_weight': 1.4939888846489393}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:00,913] Trial 23 finished with value: 0.9608972547901837 and parameters: {'n_estimators': 557, 'max_depth': 9, 'learning_rate': 0.018889057409719866, 'subsample': 0.6750231976287558, 'colsample_bytree': 0.7437726731184796, 'gamma': 7.423870757006848, 'reg_alpha': 4.480936475254343, 'reg_lambda': 7.679964694199387, 'min_child_weight': 8, 'scale_pos_weight': 2.015518224646385}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:02,272] Trial 24 finished with value: 0.9610016291307104 and parameters: {'n_estimators': 664, 'max_depth': 5, 'learning_rate': 0.010885555744860328, 'subsample': 0.6221818414537215, 'colsample_bytree': 0.7213543282249576, 'gamma': 4.961321503361119, 'reg_alpha': 3.216653729245574, 'reg_lambda': 8.968068804384313, 'min_child_weight': 9, 'scale_pos_weight': 1.4055653192027537}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:03,557] Trial 25 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 686, 'max_depth': 3, 'learning_rate': 0.013358342502564725, 'subsample': 0.611858115892433, 'colsample_bytree': 0.7223598443545783, 'gamma': 8.150052464021925, 'reg_alpha': 3.118039555367107, 'reg_lambda': 9.67989667166028, 'min_child_weight': 9, 'scale_pos_weight': 1.4091838524939866}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:05,086] Trial 26 finished with value: 0.9608197592527776 and parameters: {'n_estimators': 810, 'max_depth': 5, 'learning_rate': 0.010304702522139076, 'subsample': 0.7008566958996065, 'colsample_bytree': 0.6180776923166581, 'gamma': 7.630258314470558, 'reg_alpha': 1.8394467007663762, 'reg_lambda': 8.333277825461627, 'min_child_weight': 10, 'scale_pos_weight': 1.8740113982328517}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:06,281] Trial 27 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 649, 'max_depth': 8, 'learning_rate': 0.016954045408171522, 'subsample': 0.6191915889638194, 'colsample_bytree': 0.7179290632492972, 'gamma': 6.054026119964428, 'reg_alpha': 3.59860258811446, 'reg_lambda': 9.117281539999368, 'min_child_weight': 9, 'scale_pos_weight': 1.376608075350204}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:07,762] Trial 28 finished with value: 0.9608972547901837 and parameters: {'n_estimators': 741, 'max_depth': 13, 'learning_rate': 0.013362812444741358, 'subsample': 0.572664024857968, 'colsample_bytree': 0.7779019175888027, 'gamma': 5.274625578644278, 'reg_alpha': 2.4893075349251594, 'reg_lambda': 6.982153237196116, 'min_child_weight': 8, 'scale_pos_weight': 2.0025397982500603}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:09,597] Trial 29 finished with value: 0.9606049262394747 and parameters: {'n_estimators': 918, 'max_depth': 10, 'learning_rate': 0.018645675663568298, 'subsample': 0.6485501834131581, 'colsample_bytree': 0.6225957338288568, 'gamma': 4.481661676902578, 'reg_alpha': 0.6191026787305747, 'reg_lambda': 7.64917832018139, 'min_child_weight': 9, 'scale_pos_weight': 2.6656445272378924}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:10,592] Trial 30 finished with value: 0.9608197592527776 and parameters: {'n_estimators': 506, 'max_depth': 4, 'learning_rate': 0.02139594852676537, 'subsample': 0.5004808724747049, 'colsample_bytree': 0.7123174904323654, 'gamma': 3.267112613901473, 'reg_alpha': 7.176970022007703, 'reg_lambda': 8.662271452702281, 'min_child_weight': 9, 'scale_pos_weight': 1.6124755099743355}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:11,823] Trial 31 finished with value: 0.9609948637853172 and parameters: {'n_estimators': 598, 'max_depth': 6, 'learning_rate': 0.01239233104731175, 'subsample': 0.756013915457662, 'colsample_bytree': 0.8565484904878536, 'gamma': 4.480619947918451, 'reg_alpha': 4.691903131668925, 'reg_lambda': 6.207835986320763, 'min_child_weight': 8, 'scale_pos_weight': 1.3424111629473023}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:13,051] Trial 32 finished with value: 0.9610861087155851 and parameters: {'n_estimators': 614, 'max_depth': 6, 'learning_rate': 0.012256629221210286, 'subsample': 0.8258351743614943, 'colsample_bytree': 0.862550963733243, 'gamma': 6.079162912900282, 'reg_alpha': 3.9453446310884996, 'reg_lambda': 6.383750256732701, 'min_child_weight': 8, 'scale_pos_weight': 1.301512271886498}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:14,503] Trial 33 finished with value: 0.960988846604993 and parameters: {'n_estimators': 732, 'max_depth': 7, 'learning_rate': 0.010514128377227965, 'subsample': 0.8307480050052416, 'colsample_bytree': 0.7654522214619216, 'gamma': 6.101616603755325, 'reg_alpha': 3.796525496946354, 'reg_lambda': 7.563408834016408, 'min_child_weight': 6, 'scale_pos_weight': 1.7841177880236032}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:15,587] Trial 34 finished with value: 0.9609103842004426 and parameters: {'n_estimators': 592, 'max_depth': 5, 'learning_rate': 0.01657010361776844, 'subsample': 0.8514881538431341, 'colsample_bytree': 0.6331635400377515, 'gamma': 6.338997651571333, 'reg_alpha': 3.0567421965557644, 'reg_lambda': 6.406241287897245, 'min_child_weight': 10, 'scale_pos_weight': 1.3153206306093999}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:16,537] Trial 35 finished with value: 0.9609042388376523 and parameters: {'n_estimators': 529, 'max_depth': 4, 'learning_rate': 0.025658194442670465, 'subsample': 0.7072600589171575, 'colsample_bytree': 0.753075212977697, 'gamma': 8.0575155045103, 'reg_alpha': 5.98293949332743, 'reg_lambda': 7.23093986323615, 'min_child_weight': 8, 'scale_pos_weight': 1.6762545970355651}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:18,081] Trial 36 finished with value: 0.9610671006702752 and parameters: {'n_estimators': 838, 'max_depth': 12, 'learning_rate': 0.011758301361580526, 'subsample': 0.9074738554488704, 'colsample_bytree': 0.8553759793652507, 'gamma': 6.953736944508059, 'reg_alpha': 3.315724945124848, 'reg_lambda': 5.512998802459396, 'min_child_weight': 6, 'scale_pos_weight': 1.9561781290308433}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:19,716] Trial 37 finished with value: 0.9607932998036771 and parameters: {'n_estimators': 848, 'max_depth': 13, 'learning_rate': 0.011490435980178692, 'subsample': 0.9517775525469285, 'colsample_bytree': 0.8555641159435665, 'gamma': 6.835260918777467, 'reg_alpha': 2.028583319183983, 'reg_lambda': 5.199677028203015, 'min_child_weight': 3, 'scale_pos_weight': 2.0753894952489205}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:21,171] Trial 38 finished with value: 0.9609949919677835 and parameters: {'n_estimators': 866, 'max_depth': 14, 'learning_rate': 0.014118010509755632, 'subsample': 0.910211338551491, 'colsample_bytree': 0.8340871817062095, 'gamma': 5.650260199955321, 'reg_alpha': 3.1392386074611056, 'reg_lambda': 8.17528264106859, 'min_child_weight': 5, 'scale_pos_weight': 1.2660391183093593}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:22,427] Trial 39 finished with value: 0.9600868185013768 and parameters: {'n_estimators': 738, 'max_depth': 12, 'learning_rate': 0.021340807858315842, 'subsample': 0.9070741655001625, 'colsample_bytree': 0.9560862310774066, 'gamma': 6.564209158430875, 'reg_alpha': 3.6310684412698304, 'reg_lambda': 5.589166125917904, 'min_child_weight': 6, 'scale_pos_weight': 3.202173801290898}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:24,184] Trial 40 finished with value: 0.9607932998036771 and parameters: {'n_estimators': 942, 'max_depth': 13, 'learning_rate': 0.01127275117333564, 'subsample': 0.9971370627371741, 'colsample_bytree': 0.802888332040288, 'gamma': 3.7629166546690995, 'reg_alpha': 1.3651933827740796, 'reg_lambda': 8.948056006326304, 'min_child_weight': 3, 'scale_pos_weight': 1.7828482153823104}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:25,284] Trial 41 finished with value: 0.9609042388376523 and parameters: {'n_estimators': 604, 'max_depth': 12, 'learning_rate': 0.015548917351781275, 'subsample': 0.8087367628859278, 'colsample_bytree': 0.8617728231489189, 'gamma': 7.609852953033629, 'reg_alpha': 4.082806521588477, 'reg_lambda': 5.847014056420903, 'min_child_weight': 9, 'scale_pos_weight': 1.5329379666828573}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:26,356] Trial 42 finished with value: 0.9609103842004426 and parameters: {'n_estimators': 495, 'max_depth': 10, 'learning_rate': 0.010100918977634325, 'subsample': 0.6405851738386531, 'colsample_bytree': 0.7028854075455535, 'gamma': 6.953372241494099, 'reg_alpha': 5.445086564402552, 'reg_lambda': 7.361353314719379, 'min_child_weight': 4, 'scale_pos_weight': 1.5376321014937668}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:27,125] Trial 43 finished with value: 0.9610011816764977 and parameters: {'n_estimators': 409, 'max_depth': 9, 'learning_rate': 0.0255141594674203, 'subsample': 0.5823048212545837, 'colsample_bytree': 0.927544737161087, 'gamma': 9.051330578528221, 'reg_alpha': 4.741446359176488, 'reg_lambda': 6.419061988683306, 'min_child_weight': 7, 'scale_pos_weight': 1.206201980961719}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:27,774] Trial 44 finished with value: 0.9610011816764977 and parameters: {'n_estimators': 307, 'max_depth': 11, 'learning_rate': 0.021846322748029647, 'subsample': 0.5761905159966406, 'colsample_bytree': 0.9131080832789841, 'gamma': 8.691656213523748, 'reg_alpha': 2.743822704904342, 'reg_lambda': 4.553972366377599, 'min_child_weight': 6, 'scale_pos_weight': 1.2215175717565745}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:29,056] Trial 45 finished with value: 0.9610011816764977 and parameters: {'n_estimators': 769, 'max_depth': 14, 'learning_rate': 0.027328482098237336, 'subsample': 0.8589860987278481, 'colsample_bytree': 0.9325009389805217, 'gamma': 9.107962165114033, 'reg_alpha': 5.911487032364038, 'reg_lambda': 6.505525952118968, 'min_child_weight': 7, 'scale_pos_weight': 1.201046618046444}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:29,802] Trial 46 finished with value: 0.9609167020916234 and parameters: {'n_estimators': 418, 'max_depth': 8, 'learning_rate': 0.033359057840564664, 'subsample': 0.5887642296173334, 'colsample_bytree': 0.8768279395635201, 'gamma': 9.392714041120401, 'reg_alpha': 5.021418846083114, 'reg_lambda': 5.653091537484421, 'min_child_weight': 7, 'scale_pos_weight': 1.0023461375542104}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:30,824] Trial 47 finished with value: 0.9595065097524159 and parameters: {'n_estimators': 419, 'max_depth': 9, 'learning_rate': 0.012549448729811098, 'subsample': 0.9147303255166498, 'colsample_bytree': 0.8235962113180276, 'gamma': 5.617825802846276, 'reg_alpha': 4.044328260955378, 'reg_lambda': 9.977444661104801, 'min_child_weight': 5, 'scale_pos_weight': 4.006726445106654}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:31,555] Trial 48 finished with value: 0.9609814150513178 and parameters: {'n_estimators': 314, 'max_depth': 10, 'learning_rate': 0.014755293162863685, 'subsample': 0.5413380048360319, 'colsample_bytree': 0.9834915050083728, 'gamma': 7.314566352209042, 'reg_alpha': 2.000363987468501, 'reg_lambda': 6.186266089276899, 'min_child_weight': 8, 'scale_pos_weight': 1.9179753537055273}. Best is trial 21 with value: 0.9610861087155851.
# [I 2025-10-19 16:43:32,752] Trial 49 finished with value: 0.9609042388376523 and parameters: {'n_estimators': 683, 'max_depth': 12, 'learning_rate': 0.019176106832633256, 'subsample': 0.5505059123773418, 'colsample_bytree': 0.9204703421850029, 'gamma': 8.387523278732811, 'reg_alpha': 6.859389080658197, 'reg_lambda': 1.6983197262883118, 'min_child_weight': 7, 'scale_pos_weight': 1.6977841762399604}. Best is trial 21 with value: 0.9610861087155851.
#
# 🎯 Best Hyperparameters Found:
# {'n_estimators': 471, 'max_depth': 11, 'learning_rate': 0.018762076736582034, 'subsample': 0.7662591134439221, 'colsample_bytree': 0.7255777700507887, 'gamma': 7.949996256795501, 'reg_alpha': 4.342711681883762, 'reg_lambda': 6.657600277501226, 'min_child_weight': 8, 'scale_pos_weight': 1.3806493433723197}
#
# ✅ Model Performance on Test Set:
# Accuracy: 0.9657219973009447
# F1 Score: 0.9551931555089417
# Confusion Matrix:
#  [[ 891   74]
#  [  53 2687]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.95      0.96      3705
# weighted avg       0.97      0.97      0.97      3705

# %%
from sklearn.metrics import roc_auc_score
print("ROC-AUC:", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))
# Out:
# ROC-AUC: 0.9618739835860973
