# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s5e7/sample_submission.csv
# /kaggle/input/playground-series-s5e7/train.csv
# /kaggle/input/playground-series-s5e7/test.csv

# %%
df=pd.read_csv('/kaggle/input/playground-series-s5e7/train.csv')
df_test=pd.read_csv('/kaggle/input/playground-series-s5e7/test.csv')
df_sample_submission=pd.read_csv('/kaggle/input/playground-series-s5e7/sample_submission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (18524, 9)

# %%
df['Personality'].value_counts()
# Out:
# Personality
# Extrovert    13699
# Introvert     4825
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
print(df['Stage_fear'].unique())
print(df['Drained_after_socializing'].unique())
# Out:
# ['No' 'Yes' nan]
# ['No' nan 'Yes']

# %%
mapping = {'Yes': 1, 'No': 0}
df['Stage_fear'] = df['Stage_fear'].map(mapping)

mapping1 = {'Yes': 1, 'No': 0}
df['Drained_after_socializing'] = df['Drained_after_socializing'].map(mapping1)

mapping2 = {'Extrovert': 1, 'Introvert': 0}
df['Personality'] = df['Personality'].map(mapping2)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         0.0                      6.0            4.0
# 1   1               1.0         0.0                      7.0            3.0
# 2   2               6.0         1.0                      1.0            0.0
# 3   3               3.0         0.0                      7.0            3.0
# 4   4               1.0         0.0                      4.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        0.0                 15.0             5.0            1
# 1                        0.0                 10.0             8.0            1
# 2                        NaN                  3.0             0.0            0
# 3                        0.0                 11.0             5.0            1
# 4                        0.0                 13.0             NaN            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  float64
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  float64
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

num_cols = ['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
            'Going_outside', 'Drained_after_socializing',
            'Friends_circle_size', 'Post_frequency']

imputer = KNNImputer(n_neighbors=5)
df[num_cols] = imputer.fit_transform(df[num_cols])

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import numpy as np

num_cols = [
    'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
    'Going_outside', 'Drained_after_socializing',
    'Friends_circle_size', 'Post_frequency'
]

X = df[num_cols]
y = df['Personality']  

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 500, step=25)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
    max_depth = trial.suggest_int('max_depth', 3, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 25)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])
    ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.02, step=0.002)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        class_weight=class_weight,
        ccp_alpha=ccp_alpha,
        random_state=42,
        n_jobs=-1
    )

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1')
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)

print("\n🎯 Best Hyperparameters Found:")
print(study.best_params)

best_params = study.best_params
best_model = RandomForestClassifier(
    **best_params,
    random_state=42,
    n_jobs=-1
)
best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

print("\n✅ Model Performance on Test Set:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# [I 2025-10-16 16:33:00,165] A new study created in memory with name: no-name-2defb5a1-79c7-49ed-bb15-108e6e27a67f
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-16 16:33:10,261] Trial 0 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 250, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 24, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 0 with value: 0.9795513256289619.
# [I 2025-10-16 16:33:18,859] Trial 1 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 0 with value: 0.9795513256289619.
# [I 2025-10-16 16:33:28,006] Trial 2 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 325, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:33:32,443] Trial 3 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 150, 'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.008}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:33:36,505] Trial 4 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 125, 'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:33:47,638] Trial 5 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 250, 'criterion': 'entropy', 'max_depth': 46, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'class_weight': 'balanced', 'ccp_alpha': 0.012}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:33:57,051] Trial 6 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 325, 'criterion': 'gini', 'max_depth': 49, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.006}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:10,460] Trial 7 finished with value: 0.9796814531340136 and parameters: {'n_estimators': 475, 'criterion': 'gini', 'max_depth': 34, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.0}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:21,085] Trial 8 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 175, 'criterion': 'gini', 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:29,881] Trial 9 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 350, 'criterion': 'log_loss', 'max_depth': 5, 'min_samples_split': 24, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.008}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:42,030] Trial 10 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 425, 'criterion': 'log_loss', 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:45,146] Trial 11 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:34:55,973] Trial 12 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 375, 'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:35:04,921] Trial 13 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 275, 'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:35:16,312] Trial 14 finished with value: 0.9796817402203273 and parameters: {'n_estimators': 400, 'criterion': 'log_loss', 'max_depth': 39, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:35:30,256] Trial 15 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 500, 'criterion': 'log_loss', 'max_depth': 40, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:35:41,478] Trial 16 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 400, 'criterion': 'log_loss', 'max_depth': 42, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:35:53,669] Trial 17 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 450, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:02,294] Trial 18 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 300, 'criterion': 'gini', 'max_depth': 39, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:12,994] Trial 19 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 375, 'criterion': 'log_loss', 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:22,217] Trial 20 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:31,356] Trial 21 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:40,753] Trial 22 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:47,258] Trial 23 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:36:56,309] Trial 24 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 300, 'criterion': 'log_loss', 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:05,567] Trial 25 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 325, 'criterion': 'gini', 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:13,511] Trial 26 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 275, 'criterion': 'log_loss', 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.01}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:24,121] Trial 27 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 350, 'criterion': 'gini', 'max_depth': 44, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:31,739] Trial 28 finished with value: 0.9795886942151828 and parameters: {'n_estimators': 275, 'criterion': 'log_loss', 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:45,976] Trial 29 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 250, 'criterion': 'gini', 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:37:55,913] Trial 30 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 350, 'criterion': 'log_loss', 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.004}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:00,904] Trial 31 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:07,219] Trial 32 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:12,833] Trial 33 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:19,242] Trial 34 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 37, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:36,828] Trial 35 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 300, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:43,018] Trial 36 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:38:53,439] Trial 37 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 375, 'criterion': 'gini', 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.01}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:13,014] Trial 38 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 325, 'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:19,989] Trial 39 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 225, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 19, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:24,248] Trial 40 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:27,908] Trial 41 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 125, 'criterion': 'log_loss', 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:32,303] Trial 42 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 150, 'criterion': 'log_loss', 'max_depth': 33, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:37,590] Trial 43 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:43,347] Trial 44 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 36, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:39:52,244] Trial 45 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 150, 'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 23, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:01,420] Trial 46 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 300, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:11,488] Trial 47 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 350, 'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:22,269] Trial 48 finished with value: 0.9794396016653787 and parameters: {'n_estimators': 400, 'criterion': 'log_loss', 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.0}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:29,884] Trial 49 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 275, 'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.008}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:33,375] Trial 50 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 100, 'criterion': 'log_loss', 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:39,709] Trial 51 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:46,772] Trial 52 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 34, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:51,917] Trial 53 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:40:57,511] Trial 54 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 50, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:06,742] Trial 55 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:13,289] Trial 56 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 23, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.012}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:17,712] Trial 57 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 150, 'criterion': 'gini', 'max_depth': 33, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:25,199] Trial 58 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 275, 'criterion': 'log_loss', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:46,214] Trial 59 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 375, 'criterion': 'log_loss', 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:41:54,873] Trial 60 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 300, 'criterion': 'entropy', 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:00,258] Trial 61 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:03,865] Trial 62 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 125, 'criterion': 'log_loss', 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:09,291] Trial 63 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.006}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:16,313] Trial 64 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:26,420] Trial 65 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 350, 'criterion': 'gini', 'max_depth': 21, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:35,533] Trial 66 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:41,835] Trial 67 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:50,401] Trial 68 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 300, 'criterion': 'log_loss', 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:42:55,342] Trial 69 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 175, 'criterion': 'gini', 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:02,783] Trial 70 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 275, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:09,068] Trial 71 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 38, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:14,716] Trial 72 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 43, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:21,762] Trial 73 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:31,788] Trial 74 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 350, 'criterion': 'log_loss', 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:40,486] Trial 75 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 150, 'criterion': 'log_loss', 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:46,846] Trial 76 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 225, 'criterion': 'gini', 'max_depth': 34, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:43:51,973] Trial 77 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:01,668] Trial 78 finished with value: 0.9795886942151828 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:15,545] Trial 79 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 425, 'criterion': 'entropy', 'max_depth': 41, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:21,325] Trial 80 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 46, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:27,280] Trial 81 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:33,276] Trial 82 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:37,415] Trial 83 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:45,540] Trial 84 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 300, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:52,175] Trial 85 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 275, 'criterion': 'log_loss', 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:44:57,575] Trial 86 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 200, 'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:16,175] Trial 87 finished with value: 0.9795513256289619 and parameters: {'n_estimators': 325, 'criterion': 'log_loss', 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:22,923] Trial 88 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_split': 21, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.014}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:29,493] Trial 89 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 35, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:34,256] Trial 90 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 175, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:38,335] Trial 91 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:41,497] Trial 92 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 125, 'criterion': 'log_loss', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:46,011] Trial 93 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:50,872] Trial 94 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 175, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:54,385] Trial 95 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 150, 'criterion': 'log_loss', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None, 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:45:59,444] Trial 96 finished with value: 0.9795904630907939 and parameters: {'n_estimators': 200, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:46:08,039] Trial 97 finished with value: 0.9797281171977756 and parameters: {'n_estimators': 300, 'criterion': 'log_loss', 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.018000000000000002}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:46:14,432] Trial 98 finished with value: 0.9796816158296858 and parameters: {'n_estimators': 225, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.016}. Best is trial 2 with value: 0.9797281171977756.
# [I 2025-10-16 16:46:29,143] Trial 99 finished with value: 0.9796352388522374 and parameters: {'n_estimators': 500, 'criterion': 'log_loss', 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'ccp_alpha': 0.02}. Best is trial 2 with value: 0.9797281171977756.
#
# 🎯 Best Hyperparameters Found:
# {'n_estimators': 325, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.016}
#
# ✅ Model Performance on Test Set:
# Accuracy: 0.9654520917678813
# F1 Score: 0.9767272727272727
# Confusion Matrix:
#  [[ 891   74]
#  [  54 2686]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.95      0.95      3705
# weighted avg       0.97      0.97      0.97      3705

# %%
from sklearn.metrics import roc_auc_score
print("ROC-AUC:", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))
# Out:
# ROC-AUC: 0.95931923906055
