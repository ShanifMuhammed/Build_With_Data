# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s5e7/sample_submission.csv
# /kaggle/input/playground-series-s5e7/train.csv
# /kaggle/input/playground-series-s5e7/test.csv

# %%
df=pd.read_csv('/kaggle/input/playground-series-s5e7/train.csv')
df_test=pd.read_csv('/kaggle/input/playground-series-s5e7/test.csv')
df_sample_submission=pd.read_csv('/kaggle/input/playground-series-s5e7/sample_submission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (18524, 9)

# %%
df['Personality'].value_counts()
# Out:
# Personality
# Extrovert    13699
# Introvert     4825
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
print(df['Stage_fear'].unique())
print(df['Drained_after_socializing'].unique())
# Out:
# ['No' 'Yes' nan]
# ['No' nan 'Yes']

# %%
mapping = {'Yes': 1, 'No': 0}
df['Stage_fear'] = df['Stage_fear'].map(mapping)

mapping1 = {'Yes': 1, 'No': 0}
df['Drained_after_socializing'] = df['Drained_after_socializing'].map(mapping1)

mapping2 = {'Extrovert': 1, 'Introvert': 0}
df['Personality'] = df['Personality'].map(mapping2)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id  Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         0.0                      6.0            4.0
# 1   1               1.0         0.0                      7.0            3.0
# 2   2               6.0         1.0                      1.0            0.0
# 3   3               3.0         0.0                      7.0            3.0
# 4   4               1.0         0.0                      4.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        0.0                 15.0             5.0            1
# 1                        0.0                 10.0             8.0            1
# 2                        NaN                  3.0             0.0            0
# 3                        0.0                 11.0             5.0            1
# 4                        0.0                 13.0             NaN            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  float64
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  float64
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1190
# Stage_fear                   1893
# Social_event_attendance      1180
# Going_outside                1466
# Drained_after_socializing    1149
# Friends_circle_size          1054
# Post_frequency               1264
# Personality                     0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

num_cols = ['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
            'Going_outside', 'Drained_after_socializing',
            'Friends_circle_size', 'Post_frequency']

imputer = KNNImputer(n_neighbors=5)
df[num_cols] = imputer.fit_transform(df[num_cols])

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py:499: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(distances, out=distances)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py:499: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(distances, out=distances)

# %%
df.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import pandas as pd
import numpy as np

num_cols = [
    'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
    'Going_outside', 'Drained_after_socializing',
    'Friends_circle_size', 'Post_frequency'
]

X = df[num_cols]
y = df['Personality']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

def objective_knn(trial):
    params = {
        'n_neighbors': trial.suggest_int('n_neighbors', 3, 20),
        'weights': trial.suggest_categorical('weights', ['uniform', 'distance']),
        'p': trial.suggest_int('p', 1, 2)  # 1=Manhattan, 2=Euclidean
    }
    model = KNeighborsClassifier(**params)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1_macro')
    return scores.mean()

def objective_svm(trial):
    params = {
        'C': trial.suggest_float('C', 0.1, 10.0, log=True),
        'kernel': trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly']),
        'gamma': trial.suggest_categorical('gamma', ['scale', 'auto']),
        'degree': trial.suggest_int('degree', 2, 5),
    }
    model = SVC(**params, class_weight='balanced', random_state=42)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1_macro')
    return scores.mean()

def objective_nb(trial):
    params = {
        'var_smoothing': trial.suggest_float('var_smoothing', 1e-12, 1e-6, log=True)
    }
    model = GaussianNB(**params)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=skf, scoring='f1_macro')
    return scores.mean()

print("\n🚀 Tuning KNN...")
study_knn = optuna.create_study(direction='maximize')
study_knn.optimize(objective_knn, n_trials=30, show_progress_bar=True)

print("\n🚀 Tuning SVM...")
study_svm = optuna.create_study(direction='maximize')
study_svm.optimize(objective_svm, n_trials=30, show_progress_bar=True)

print("\n🚀 Tuning Naive Bayes...")
study_nb = optuna.create_study(direction='maximize')
study_nb.optimize(objective_nb, n_trials=30, show_progress_bar=True)

best_knn = KNeighborsClassifier(**study_knn.best_params)
best_svm = SVC(**study_svm.best_params, class_weight='balanced', random_state=42)
best_nb = GaussianNB(**study_nb.best_params)

best_knn.fit(X_train, y_train)
best_svm.fit(X_train, y_train)
best_nb.fit(X_train, y_train)

y_pred_knn = best_knn.predict(X_test)
y_pred_svm = best_svm.predict(X_test)
y_pred_nb = best_nb.predict(X_test)

print("\n🎯 Best KNN Params:", study_knn.best_params)
print("🎯 Best SVM Params:", study_svm.best_params)
print("🎯 Best Naive Bayes Params:", study_nb.best_params)

results = pd.DataFrame({
    'Model': ['KNN', 'SVM', 'Naive Bayes'],
    'Accuracy': [
        accuracy_score(y_test, y_pred_knn),
        accuracy_score(y_test, y_pred_svm),
        accuracy_score(y_test, y_pred_nb)
    ],
    'F1 Score (Macro)': [
        f1_score(y_test, y_pred_knn, average='macro'),
        f1_score(y_test, y_pred_svm, average='macro'),
        f1_score(y_test, y_pred_nb, average='macro')
    ]
})

print("\n📊 Model Comparison:\n")
print(results)

print("\n🧩 Detailed Reports:")
print("\n--- KNN ---")
print(classification_report(y_test, y_pred_knn))
print("\n--- SVM ---")
print(classification_report(y_test, y_pred_svm))
print("\n--- Naive Bayes ---")
print(classification_report(y_test, y_pred_nb))
# Out:
# [I 2025-10-19 17:15:25,779] A new study created in memory with name: no-name-20eb479c-ae63-4ce5-a14b-2a2ce20c65e7
# 🚀 Tuning KNN...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-10-19 17:15:26,821] Trial 0 finished with value: 0.9607414225587296 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9607414225587296.
# [I 2025-10-19 17:15:27,885] Trial 1 finished with value: 0.9607414225587296 and parameters: {'n_neighbors': 18, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9607414225587296.
# [I 2025-10-19 17:15:28,858] Trial 2 finished with value: 0.9606634238482064 and parameters: {'n_neighbors': 12, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9607414225587296.
# [I 2025-10-19 17:15:29,665] Trial 3 finished with value: 0.9568520651050992 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9607414225587296.
# [I 2025-10-19 17:15:29,954] Trial 4 finished with value: 0.9485762604359529 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9607414225587296.
# [I 2025-10-19 17:15:30,912] Trial 5 finished with value: 0.9607477587613438 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'p': 1}. Best is trial 5 with value: 0.9607477587613438.
# [I 2025-10-19 17:15:31,302] Trial 6 finished with value: 0.9543932190428082 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9607477587613438.
# [I 2025-10-19 17:15:32,133] Trial 7 finished with value: 0.9582260655938521 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 5 with value: 0.9607477587613438.
# [I 2025-10-19 17:15:33,091] Trial 8 finished with value: 0.9607479809789279 and parameters: {'n_neighbors': 18, 'weights': 'uniform', 'p': 2}. Best is trial 8 with value: 0.9607479809789279.
# [I 2025-10-19 17:15:33,957] Trial 9 finished with value: 0.9603009958092906 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 2}. Best is trial 8 with value: 0.9607479809789279.
# [I 2025-10-19 17:15:34,419] Trial 10 finished with value: 0.9556212413094223 and parameters: {'n_neighbors': 20, 'weights': 'distance', 'p': 2}. Best is trial 8 with value: 0.9607479809789279.
# [I 2025-10-19 17:15:35,343] Trial 11 finished with value: 0.9607479809789279 and parameters: {'n_neighbors': 15, 'weights': 'uniform', 'p':
 'kernel': 'rbf', 'gamma': 'auto', 'degree': 2}. Best is trial 20 with value: 0.9611451900647813.
#
# 🚀 Tuning Naive Bayes...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-10-19 17:21:25,124] Trial 0 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.4905944514341589e-12}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,162] Trial 1 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 5.973208322855093e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,200] Trial 2 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.0038187863029627e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,238] Trial 3 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.3151323903624413e-11}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,275] Trial 4 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.0281499955973037e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,313] Trial 5 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 6.424644283622406e-09}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,352] Trial 6 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.7094864023598824e-12}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,387] Trial 7 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.44385644291305e-11}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,424] Trial 8 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.3160265372808621e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,461] Trial 9 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 6.0374935262969045e-09}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,499] Trial 10 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 7.46229283775885e-07}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,538] Trial 11 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 8.636016394359856e-07}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,579] Trial 12 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.057605417978182e-07}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,617] Trial 13 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.1030904016252626e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,656] Trial 14 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 7.430781689921898e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,697] Trial 15 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.0204232535497572e-12}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,734] Trial 16 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 7.760749969439145e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,774] Trial 17 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 6.979015672685096e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,816] Trial 18 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 6.102088472930444e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,854] Trial 19 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 5.91196641503752e-11}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,893] Trial 20 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.3878806732828924e-11}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,940] Trial 21 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.389142956731882e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:25,980] Trial 22 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 1.2392925172493848e-09}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,021] Trial 23 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.1167087163167003e-09}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,061] Trial 24 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.0853233207603114e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,098] Trial 25 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 4.886127698685313e-12}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,147] Trial 26 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.420703479156214e-07}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,197] Trial 27 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.7343793755538513e-08}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,236] Trial 28 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 3.1607391950120126e-10}. Best is trial 0 with value: 0.9605922759395675.
# [I 2025-10-19 17:21:26,276] Trial 29 finished with value: 0.9605922759395675 and parameters: {'var_smoothing': 2.8190057147896526e-11}. Best is trial 0 with value: 0.9605922759395675.
#
# 🎯 Best KNN Params: {'n_neighbors': 14, 'weights': 'uniform', 'p': 2}
# 🎯 Best SVM Params: {'C': 2.3393072904561283, 'kernel': 'rbf', 'gamma': 'auto', 'degree': 3}
# 🎯 Best Naive Bayes Params: {'var_smoothing': 1.4905944514341589e-12}
#
# 📊 Model Comparison:
#
#          Model  Accuracy  F1 Score (Macro)
# 0          KNN  0.965722          0.955224
# 1          SVM  0.965182          0.954581
# 2  Naive Bayes  0.964372          0.953509
#
# 🧩 Detailed Reports:
#
# --- KNN ---
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.95      0.96      3705
# weighted avg       0.97      0.97      0.97      3705
#
#
# --- SVM ---
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.95      0.95      3705
# weighted avg       0.97      0.97      0.97      3705
#
#
# --- Naive Bayes ---
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       965
#            1       0.97      0.98      0.98      2740
#
#     accuracy                           0.96      3705
#    macro avg       0.96      0.95      0.95      3705
# weighted avg       0.96      0.96      0.96      3705
